# %%
#df[condition/conditions][column/list of columns]


import pandas as pd
import numpy as np

excel_file = pd.read_excel(r"C:\Users\adead\Downloads\excel dataset for practice\Financial Sample.xlsx")
df = pd.DataFrame(excel_file)
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df  == "Canada"
# Out:
#      Segment  Country  Product  Discount Band  Units Sold  \
# 0      False     True    False          False       False
# 1      False    False    False          False       False
# 2      False    False    False          False       False
# 3      False    False    False          False       False
# 4      False    False    False          False       False
# ..       ...      ...      ...            ...         ...
# 695    False    False    False          False       False
# 696    False    False    False          False       False
# 697    False    False    False          False       False
# 698    False     True    False          False       False
# 699    False    False    False          False       False
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts   Sales   COGS  \
# 0                  False       False        False      False   False  False
# 1                  False       False        False      False   False  False
# ...

# %%
# To return the actual df

df[df == "Canada"]
# Out:
#     Segment Country Product Discount Band  Units Sold  Manufacturing Price  \
# 0       NaN  Canada     NaN           NaN         NaN                  NaN
# 1       NaN     NaN     NaN           NaN         NaN                  NaN
# 2       NaN     NaN     NaN           NaN         NaN                  NaN
# 3       NaN     NaN     NaN           NaN         NaN                  NaN
# 4       NaN     NaN     NaN           NaN         NaN                  NaN
# ..      ...     ...     ...           ...         ...                  ...
# 695     NaN     NaN     NaN           NaN         NaN                  NaN
# 696     NaN     NaN     NaN           NaN         NaN                  NaN
# 697     NaN     NaN     NaN           NaN         NaN                  NaN
# 698     NaN  Canada     NaN           NaN         NaN                  NaN
# 699     NaN     NaN     NaN           NaN         NaN                  NaN
#
# ...

# %%
# return the column
df[df == "Canada"]["Country"]
# Out:
# 0      Canada
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 695       NaN
# 696       NaN
# 697       NaN
# 698    Canada
# 699       NaN
# Name: Country, Length: 700, dtype: object

# %%
# multiple columns
df[df == 742500.0][["Country", "Manufacturing Price"]]
# Out:
#     Country  Manufacturing Price
# 0       NaN                  NaN
# 1       NaN                  NaN
# 2       NaN                  NaN
# 3       NaN                  NaN
# 4       NaN                  NaN
# ..      ...                  ...
# 695     NaN                  NaN
# 696     NaN                  NaN
# 697     NaN                  NaN
# 698     NaN                  NaN
# 699     NaN                  NaN
#
# [700 rows x 2 columns]

# %%
df[df == "Germany"][["Gross Sales", "Gross Sales"]]
# Out:
#      Gross Sales  Gross Sales
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 695          NaN          NaN
# 696          NaN          NaN
# 697          NaN          NaN
# 698          NaN          NaN
# 699          NaN          NaN
#
# [700 rows x 2 columns]
