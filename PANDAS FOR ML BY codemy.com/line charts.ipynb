# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt


csv_file = pd.read_csv(r"C:\Users\adead\Downloads\csv dataset for practice\diabetes.csv")
df = pd.DataFrame(csv_file)

df.head(20)
df['Insulin'].describe()
# Out:
# count    768.000000
# mean      79.799479
# std      115.244002
# min        0.000000
# 25%        0.000000
# 50%       30.500000
# 75%      127.250000
# max      846.000000
# Name: Insulin, dtype: float64

# %%
# line plot
df.plot(kind = "line")
plt.show()

# %%
# default is kind = "line"

# %%
# df.plot(kind= "line", SHIFT + TAB)
# width
df['Insulin'].plot(kind = "line", lw = 10)
plt.show()

# %%
# parameters
df['Insulin'].plot(kind = "line", lw = 2, figsize = (12, 6), legend = True, grid = True, xlabel = "Index", ylabel = "Data", stacked = True, table = True)
plt.show()
